# %%
import pandas as pd
broader_taxanomy=pd.read_csv("broader_taxanomy.csv",header=None)[0].str.lower().tolist()
meta_taxanomy=pd.read_csv("meta_taxanomy.csv",header=None)[0].str.lower().tolist()
model_taxanomy=pd.read_csv("model_taxanomy.csv",header=None)[0].str.lower().tolist()

# %%
import pylab as plt
from matplotlib_venn import venn3, venn3_circles
from matplotlib_venn import venn2

model = set(model_taxanomy)
meta = set(meta_taxanomy)
broader = set(broader_taxanomy)

# %%
v=venn3([model, meta, broader], ('model', 'meta', 'broader'))
plt.show()
